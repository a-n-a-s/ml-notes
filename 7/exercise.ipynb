# %%
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('hr_data.csv')
y_list = df.drop(['left'],axis="columns")
y_list
# Out:
#       satisfaction_level  last_evaluation  number_project  \
# 0                   0.38             0.53               2
# 1                   0.80             0.86               5
# 2                   0.11             0.88               7
# 3                   0.72             0.87               5
# 4                   0.37             0.52               2
# ...                  ...              ...             ...
# 4995                0.67             0.55               5
# 4996                0.53             0.92               4
# 4997                0.77             0.59               5
# 4998                0.57             0.82               5
# 4999                0.64             0.97               4
#
#       average_montly_hours  time_spend_company  Work_accident  \
# 0                      157                   3              0
# 1                      262                   6              0
# 2                      272                   4              0
# 3                      223                   5              0
# 4                      159                   3              0
# ...                    ...                 ...            ...
# 4995                   193                   3              0
# 4996                   223                   3              1
# 4997                   189                   5              0
# 4998                   138                   3              0
# 4999                   268                   2              0
#
#       promotion_last_5years Department  salary
# 0                         0      sales     low
# 1                         0      sales  medium
# 2                         0      sales  medium
# 3                         0      sales     low
# 4                         0      sales     low
# ...                     ...        ...     ...
# 4995                      0  technical     low
# 4996                      0  technical     low
# 4997                      0  technical     low
# 4998                      0  technical     low
# 4999                      0  technical     low
#
# [5000 rows x 9 columns]

# %% [markdown]
# From the data analysis so far we can conclude that we will use following variables as independant variables in our model
# **Satisfaction Level**
# **Average Monthly Hours**
# **Promotion Last 5 Years**
# **Salary**

# %%
subdf = df[['satisfaction_level','average_montly_hours','promotion_last_5years','salary']]
subdf.head()
# Out:
#    satisfaction_level  average_montly_hours  promotion_last_5years  salary
# 0                0.38                   157                      0     low
# 1                0.80                   262                      0  medium
# 2                0.11                   272                      0  medium
# 3                0.72                   223                      0     low
# 4                0.37                   159                      0     low

# %%
salary_dummies = pd.get_dummies(subdf['salary'])
df_with_dummies = pd.concat([subdf,salary_dummies], axis="columns")
df_with_dummies
# Out:
#       satisfaction_level  average_montly_hours  promotion_last_5years  salary  \
# 0                   0.38                   157                      0     low
# 1                   0.80                   262                      0  medium
# 2                   0.11                   272                      0  medium
# 3                   0.72                   223                      0     low
# 4                   0.37                   159                      0     low
# ...                  ...                   ...                    ...     ...
# 4995                0.67                   193                      0     low
# 4996                0.53                   223                      0     low
# 4997                0.77                   189                      0     low
# 4998                0.57                   138                      0     low
# 4999                0.64                   268                      0     low
#
#       high  low  medium
# 0        0    1       0
# 1        0    0       1
# 2        0    0       1
# 3        0    1       0
# 4        0    1       0
# ...    ...  ...     ...
# 4995     0    1       0
# 4996     0    1       0
# 4997     0    1       0
# 4998     0    1       0
# 4999     0    1       0
#
# [5000 rows x 7 columns]

# %%
X=df_with_dummies.drop(['salary'],axis="columns")
X.head()
# Out:
#    satisfaction_level  average_montly_hours  promotion_last_5years  high  low  \
# 0                0.38                   157                      0     0    1
# 1                0.80                   262                      0     0    0
# 2                0.11                   272                      0     0    0
# 3                0.72                   223                      0     0    1
# 4                0.37                   159                      0     0    1
#
#    medium
# 0       0
# 1       1
# 2       1
# 3       0
# 4       0

# %%
Y=df.left
Y.head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: left, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train , X_test , Y_train , Y_test = train_test_split(X,Y,train_size=0.8)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
model.fit(X_train, Y_train)
# Out:
# LogisticRegression()

# %%
model.score(X_test,Y_test)
# Out:
# 0.737
